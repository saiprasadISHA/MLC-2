# %%
transaction=[
    {"Bread","Milk","Eggs"},
    {"Bread","Milk"},
    {"Milk","Eggs"},
    {"Bread","Eggs"},
    {"Bread","Milk","Eggs"}
]
print(transaction)
# Out:
# [{'Eggs', 'Milk', 'Bread'}, {'Milk', 'Bread'}, {'Eggs', 'Milk'}, {'Eggs', 'Bread'}, {'Eggs', 'Milk', 'Bread'}]
