# %%
#ECLAT theoram
transactions=[
    {"A","B"},
    {"A","C"},
    {"B","C"},
    {"A","B"},
]

min_sup=2
tid={}
for i,t in enumerate(transactions):
    for item in t:
        if item not in tid:
            tid[item]=set()
        tid[item].add(i)
print(tid)

# Step 2: Intersect manually example: (A and B)
AB=tid["A"] & tid["B"]     # core idea of ECLAT
print("Support of (A,B):",len(AB))

# Step 3: Check if frequent
if len(AB)>=min_sup:
    print("(A,B) is frequent")

# %%
'''
It works using the principle of bootstarp sampling method. Given a training dataset D containing m examples, bootstraping samples draws a 
draws a example __ by selecting
* Run all the classifiers on the impu and choose the class with the maximum number of boards
'''
# Out:
# '\nIt works using the principle of bootstarp sampling method. Given a training dataset D containing m examples, bootstraping samples draws a \ndraws a example __ by selecting\n* Run all the classifiers on the impu and choose the class with the maximum number of boards\n'

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score

X,y = make_classification(n_samples=500, n_features=5, random_state=0)
Xtr, Xte, ytr, yte = train_test_split(X, y, test_size=0.3, random_state=0)
bag = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=20,
    bootstrap=True,
)
bag.fit(Xtr, ytr)
print("Bagging Accuracy:", accuracy_score(yte, bag.predict(Xte)))
# Out:
# Bagging Accuracy: 0.9133333333333333

# %%
# Implementation of boosting using Adaboost

from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

ada=AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=1),  # weak learner
    n_estimators=50,
    learning_rate=1.0,
    random_state=0
)
ada.fit(Xtr,ytr)
print("AdaBoost accuracy:", accuracy_score(yte,ada.predict(Xte)))
# Out:
# AdaBoost accuracy: 0.86

# %%
# Implementation of Gradient boosting Classifier

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

gbm=GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
gbm.fit(Xtr,ytr)
print("GBM accuracy:",accuracy_score(yte, gbm.predict(Xte)))
# Out:
# GBM accuracy: 0.9266666666666666

# %%
# Implementation of Elastic net
# This code shows how Elastic Net regresson

from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error

# Create simple regression data
X,y=make_regression(n_samples=200, n_features=5, noise=10, random_state=0)

# Split
Xtr, Xte, ytr, yte = train_test_split(X, y, test_size=0.3, random_state=0)

# Elastic Net Model
model=ElasticNet(alpha=1.0, l1_ratio=0.5)
# alpha=regularization strength
# l1_ratio=balance (0=L2 only, 1=L1 only)

model.fit(Xtr, ytr)

# Predict
y_pred=model.predict(Xte)
print("MSE:",mean_squared_error(yte,y_pred))
# Out:
# MSE: 1005.7291576108645
