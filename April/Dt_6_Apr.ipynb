# %%
'''
Reinforcement Learning Algorithm

Dynamic Programming:-
-It refers to the class of algorithms used in reinforcement learining to compute optimal policies and value functions when the complete model 
of the environemnt is known. These methods are mainly used for solving markup descision process.
-The key idea is to search for the optimal policy by using the value functions where the problem is broken down into 
multiple sub problems and the result of a sub-problem is used in similar sub problems instead of independentley 
solving these.
-In dynamic programming the key concept is to identify the value function that will satify the Bellman Eqn then using tthe optimal value 
function to identify the optimal policy.

Policy Evaluation:-
-Policy evaluation is the process of computing the state value function   for given 
-The value function repesents an extended income starting from state S and following policy (pi).
-The policy equation is based on the Bellman's equation 

Initiaise Vpi(S)=0
Update the  value of each state using the Bellman's equation.
Repeat the update for each states.
Continue the 

Policy Improvement:-
It is an important conceptn reinforcemnt learnng used to obtain the better policy from an exisiting policy
-The goal of policy improvent is to modify the current policy so that it yields higher expected returns as er the vlaue 
functions
- The improvemnt policy 

Policy Iteration:-
-It is a dynamic algoritm that finds the obtained policy that finds the optimal policy by repeadly performing the 
policy evaluation initialise the policy

Repeat the evaluation

Value Iteration:-
-It is simplified version policy iteration that combines a policy evaluation and policy improvement in a single state.

Steps
1) Initialise V(s)
2) Update vlaues using a value iteration formula
3) Repeat updates until vlaue coverges
4) Extract the potimal plicy for the final value function

Generalised Policy Iteration (GPI):-
-It is a term that is used to identify the idea of letting the policy evaluartion and plicy improvemnt interact, 
indepentof the granularity of the queue processes.
-The policy is being improved with being    and the value function is being driven for the value function to the policy.
-The vlaue fnction stabilised once, it is consuistent with the current policy and the policy sytabilise once, it is greedy
for the current vlaue function.
-Thus the cycle stops once both the process stabilise as it reaches the Bellman optiality equation and the policy 
and the value are optimal.
'''
